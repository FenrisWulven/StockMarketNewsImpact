# %%
import pandas as pd

# Load the CSV file
df = pd.read_csv(r'C:\Users\jbh\Desktop\CompTools\concat_data.csv')

# Print value counts of the symbol column
print("Value counts for symbols:")
print(df['symbol'].value_counts())

# Print total number of articles
print(f"\nTotal number of articles: {len(df)}")

# Print date range
print(f"\nDate range:")
print(f"Start: {df['datetime'].min()}")
print(f"End: {df['datetime'].max()}")
# Out:
# Value counts for symbols:
# symbol
# GOOGL    3901
# AAPL     3658
# TSLA     3329
# AMZN     3319
# MSFT     2790
# NVDA     1609
# META      273
# Name: count, dtype: int64
#
# Total number of articles: 18879
#
# Date range:
# Start: 2021-01-02 13:28:07+00:00
# End: 2023-12-29 16:31:00+00:00

# %%
df
# Out:
#       symbol        company_name  sentiment_score  \
# 0       AMZN    Amazon.com, Inc.         0.318200
# 1       AAPL           Apple Inc         0.385200
# 2       TSLA           Tesla Inc         0.238350
# 3       AAPL           Apple Inc         0.354800
# 4       TSLA           Tesla Inc         0.047367
# ...      ...                 ...              ...
# 18874  GOOGL       Alphabet Inc.         0.423867
# 18875   META  Meta Platforms Inc         0.353329
# 18876  GOOGL       Alphabet Inc.         0.567371
# 18877   TSLA         Tesla, Inc.         0.058682
# 18878  GOOGL       Alphabet Inc.         0.348750
#
#                                                    title  \
# 0               Will Shopify Stock Reach $2,000 By 2022?
# 1      Apple iPhone Christmas Sales Smash Expectation...
# 2      Benzinga's Final Bulls And Bears Of The Year: ...
# 3      Benzinga's Final Bulls And Bears Of The Year: ...
# 4              Tesla Vehicle Production Hit 509,737 – 24
# ...
